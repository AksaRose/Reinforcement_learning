# %% [markdown]
# <a href="https://colab.research.google.com/github/AksaRose/Reinforcement_learning/blob/main/cartpole_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium[classic-control] imageio

# %%
import gymnasium as gym
import imageio
from IPython.display import Image

env = gym.make('CartPole-v1',render_mode="rgb_array")

# %%
observation,info = env.reset()
print(f"observation:{observation}")
print(f"info:{info}")
#cart postion,cart velocity,pole angle,pole_angular velocity
# Out:
# observation:[-0.00571665 -0.03625513 -0.03666129  0.00372585]
# info:{}

# %%
episode_over = False
total_reward = 0
frames = []

# %%
while not episode_over:
  action = env.action_space.sample()
  observation, reward, terminated, truncated, info = env.step(action)
  frames.append(env.render())

  total_reward += reward
  episode_over = terminated or truncated

print(f"Episode finished!tostal; reward {total_reward}")
env.close()
# Out:
# Episode finished!tostal; reward 17.0

# %%
imageio.mimsave('/content/cartpole.gif', frames, fps=30)
Image(filename='/content/cartpole.gif')
